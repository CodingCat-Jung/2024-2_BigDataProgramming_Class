# %% [markdown]
# <a href="https://colab.research.google.com/github/CodingCat-Jung/2024-2_BigDataProgramming_Class/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_11%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv'

titanic_df = pd.read_csv(url, sep='\t')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

url = 'https://github.com/sehakflower/data/blob/main/titanic.xlsx?raw=true'

titanic_df = pd.read_excel(url, sheet_name = 'titanic3')
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
import pandas as pd

url = 'https://github.com/sehakflower/data/blob/main/titanic.xlsx?raw=true'

titanic = pd.read_excel(url, sheet_name = 'titanic3')
titanic.head()
# head() / tail() 실데이터 미리보기 가능. default = 5
# 인자값으로 정수를 지정하면 해당하는 라인 수 만큼 표시

titanic.shape
titanic.info()
titanic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# ...

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv'

titanic_df = pd.read_csv(url, sep='\t')

new_columns = ['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
       'parch', 'ticket', 'fare', 'cabin', 'embarked']

titanic_df.columns = new_columns
titanic_df.columns

copy_titanic_df = titanic_df.copy()
# 복사본 데이터프레임 만들어놓기
copy_titanic_df.head()

# copy_titanic_df['새로운 열 이름'] = []

# 행 추가하기 - appand()
# new_data = {'passid': , ... }
# copy_titanic_df.appand(new_data)

copy_titanic_df['gender'] = 1
copy_titanic_df.head()

copy_titanic_df.index
copy_titanic_df.values

copy_titanic_df.sort_index(ascending=False)

copy_titanic_df.sort_values(by='age', ascending=False)
copy_titanic_df.sort_values(by=['age', 'pclass'], ascending=False)

# 행에서 지정된 범위만큼 읽어오기 [시작인덱스:종료인덱스:간격]
copy_titanic_df[0:5] # 0 ~ 4
copy_titanic_df[0:1]
copy_titanic_df[::3] # 3개씩 건너서 출력
copy_titanic_df[::-1] # 역순으로 출력

# 열에서 지정된 범위만큼 읽어오기
copy_titanic_df[copy_titanic_df.columns[4]][0:5]
copy_titanic_df['name'][0:5]
copy_titanic_df[['name', 'age']][0:5]

# print( copy_titanic_df[copy_titanic_df.columns[4]]   [3] )
# print( copy_titanic_df['age']   [3] )
# print( copy_titanic_df[copy_titanic_df.columns[4]]   [::-1] )

copy_titanic_df.loc[0]
copy_titanic_df.loc[0:5]

copy_titanic_df.set_index('name')
copy_titanic_df.reset_index()
# Out:
#      index  passengerId  survived  pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 151    151          152         1       1
# 152    152          153         0       3
# 153    153          154         0       3
# 154    154          155         0       3
# 155    155          156         0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
import pandas as pd

url = 'https://github.com/sehakflower/data/blob/main/titanic_1309.xlsx?raw=true'
titanic = pd.read_excel(url, sheet_name = 'total')
titanic

t_1000 = titanic.iloc[0:1000]
t_309 = titanic.iloc[1000:]

t_1000.to_csv('t_1000.csv')
t_309.to_csv('t_309.csv')

total_df = pd.concat([t_1000, t_309])
total_df

df1 = t_1000[['name', 'pclass', 'sex', 'age']]
df2 = t_1000[['name', 'survived']]

merge_df = pd.merge(df1, df2, on='name')
merge_df

titanic.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
import pandas as pd
from datetime import datetime, date, time

file_list = ['2009_hr.xlsx', '2010_hr.xlsx', '2011_hr.xlsx', '2012_hr.xlsx', '2013_hr.xlsx', '2014_hr.xlsx', '2015_hr.xlsx', '2016_hr.xlsx']

df = pd.DataFrame()

for f in file_list:
  data = pd.read_excel(f)
  df = pd.concat([df, data])

# df.info()
# df.describe()

df2 = df.reset_index(drop=True)
# df2.info()
df2.head()

df['Date'] = pd.to_datetime(df['날짜'], format = '%Y%m%d') + pd.to_timedelta(df['시간'].astype(int), unit = 'h')

df.set_index(df['Date'], inplace = True)

df1 = df[['수온(℃)', '수위(el.m)', 'EC(㎲/㎝)']]
df1.columns = ['temp', 'level', 'EC']

df1.isnull().sum

df1.to_csv('water.csv', encoding= 'cp949')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('water.csv', index_col='Date', parse_dates=True, encoding= 'cp949')
# df.describe()
# df.head()
# df.info()

# df.hist(bins=50, figsize=(10,6))
# plt.show()

# df.boxplot()

# plt.subplot(1, 3, 1)
# df.boxplot(column='temp', return_type='both')

# plt.subplot(1, 3, 2)
# df.boxplot(column='level', return_type='both')

# plt.subplot(1, 3, 3)
# df.boxplot(column='EC', return_type='both')
# plt.show()

# plt.subplot(3, 1, 1)
# df['temp'].plot()

# plt.subplot(3, 1, 2)
# df['level'].plot()

# plt.subplot(3, 1, 3)
# df['EC'].plot()
# plt.show()

#IQR을 이용하여 이상치 처리
# quantile()
q3_level = df['level'].quantile(q = 0.75)
q1_level = df['level'].quantile(q = 0.25)
iqr_level = q3_level - q1_level
# print(iqr_level)

upper_level = q3_level + 1.5 * iqr_level
lower_level = q1_level - 1.5 * iqr_level

print(upper_level, '/', lower_level)

print((df['level'] > upper_level).sum())
print((df['level'] < lower_level).sum())

# 이상치 데이터 제거
df_iqr_level = df[(df['level'] < upper_level) & (df['level'] > lower_level)]
df_iqr_level['level'].plot()


# 수온 데이터
# quantile()
q3_temp = df['temp'].quantile(q = 0.75)
q1_temp = df['temp'].quantile(q = 0.25)
iqr_temp = q3_temp - q1_temp

upper_temp = q3_temp + 1.5 * iqr_temp
lower_temp = q1_temp - 1.5 * iqr_temp

print(upper_temp, '/', lower_temp)

df_iqr_temp = df[(df['temp'] < upper_temp) & (df['temp'] > lower_temp)]
df_iqr_temp['temp'].plot()
# Out:
# 44.81999999999999 / 44.099999999999994
# 4492
# 1273
# 16.450000000000003 / 16.049999999999997
# <Axes: xlabel='Date'>
